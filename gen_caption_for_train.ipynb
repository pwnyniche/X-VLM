# %%
from dataset import create_dataset, create_sampler, create_loader
from models.model_nlvr import XVLM
from models.model_captioning import XVLM
from models import XVLMBase, build_mlp, load_pretrained

config = {'train_file': ['data/finetune/cosmos_train.json'], 'val_file': ['data/finetune/cosmos_val.json'], 
'test_file': ['data/finetune/cosmos_test.json'], 'image_root': 'images/cosmos/', 
'vision_config': 'configs/config_swinB_384.json', 'use_clip_vit': False, 'use_swin': True, 
'image_res': 384, 'patch_size': 32, 'use_roberta': False, 'text_config': 'configs/config_bert.json', 
'text_encoder': 'data/bert-base-uncased', 'num_dec_layers': 6, 'batch_size_train': 5, 
'batch_size_test': 32, 'max_tokens': 40, 'label_smoothing': 0.1, 'max_length': 20, 'min_length': 5, 
'num_beams': 3, 'prompt': 'a picture of ', 'optimizer': {'opt': 'adamW', 'lr': 1e-05, 
'weight_decay': 0.01, 'lr_mult': 2}, 'schedular': {'sched': 'linear', 'lr': 1e-05, 'epochs': 5, 
'num_warmup_steps': 0.1}, 'start_eval': 0}
train_dataset, val_dataset, test_dataset = create_dataset('cosmos', config);
datasets = [train_dataset, val_dataset, test_dataset]
# config_vqa['pad_token_id'] = train_dataset.pad_token_id
# config_vqa['eos'] = train_dataset.eos_token
# Out:
# /root/anaconda3/envs/xvlm/lib/python3.9/site-packages/torchvision/transforms/transforms.py:834: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# /root/anaconda3/envs/xvlm/lib/python3.9/site-packages/torchvision/transforms/transforms.py:280: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(

# %%
train_loader, val_loader, test_loader = create_loader(datasets, [None, None, None], batch_size=[5,5,5],
                                                          num_workers=[4, 4, 4], is_trains=[True, False, False],
                                                          collate_fns=[None, None, None])

# %%
model = XVLM(config=config)
model.load_pretrained('coco_capt_cider_step_44275.th', config, is_eval=False)
model = model.to('cuda:1');
# Out:
# ### Loading pretrained vision encoder
# ### Loading pretrained text encoder
# load_capt_pretrain,  False
# ### Loading pretrained text encoder
# load checkpoint from coco_capt_cider_step_44275.th
# missing_keys:  []
# unexpected_keys:  []

# %%
import json
train_data = list(
    map(json.loads, open(f"/root/thesis/ViLT/cosmos/train_data.json").readlines())
)

# %%
from torchvision import transforms
from dataset.randaugment import RandomAugment
normalize = transforms.Normalize((0.48145466, 0.4578275, 0.40821073), (0.26862954, 0.26130258, 0.27577711))
train_transform = transforms.Compose([
        transforms.RandomResizedCrop(config['image_res'], scale=(0.5, 1.0),
                                     interpolation=Image.BICUBIC),
        transforms.RandomHorizontalFlip(),
        RandomAugment(2, 7, isPIL=True, augs=['Identity', 'AutoContrast', 'Equalize', 'Brightness', 'Sharpness',
                                              'ShearX', 'ShearY', 'TranslateX', 'TranslateY', 'Rotate']),
        transforms.ToTensor(),
        normalize,
    ])
# Out:
# /tmp/ipykernel_1333165/3429474641.py:6: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   interpolation=Image.BICUBIC),

# %%
from PIL import Image
import os
image_path = os.path.join(config['image_root'], train_data[0]['img_local_path'])
image = Image.open(image_path).convert('RGB')
image = train_transform(image)

# %%
len(train_data)
np.array_split(train_data)
# Out:
# 161754

# %%
train_data[0]['img_local_path']
train_data[1]['img_local_path']
train_data[2]['img_local_path']
train_data[3]['img_local_path']
train_data[4]['img_local_path']
# Out:
# 'train/2.jpg'

# %%
import torch
from tqdm import tqdm
import numpy as np
torch.manual_seed(42)

device='cuda:1'
# model.to(device)
image_cap_dict = {}
batch_size = 10
for i in tqdm(range(0, len(train_data), batch_size)):
    # image_batch = torch.empty()
    z=False
    array=[]
    keys = []
    for data in train_data[i:i+batch_size]:
        key = data['img_local_path']
        keys.append(key)
        image_path = os.path.join(config['image_root'], key)
        image = Image.open(image_path).convert('RGB')
        image = train_transform(image)
        array.append(image)
        # if z == False:
        #     image_batch = image
        #     z=True
        # image_batch = torch.stack([image_batch,image])
    image_batch = torch.stack(array)
    image_batch = image_batch.to(device)
    
    c = model.generate(image_batch,num_return_sequences=1,sample=True, num_beams=1)
    image_cap_dict[keys[0]] = c[0][0]
    image_cap_dict[keys[1]] = c[0][1]
    image_cap_dict[keys[2]] = c[0][2]
    image_cap_dict[keys[3]] = c[0][3]
    image_cap_dict[keys[4]] = c[0][4]

# for data in tqdm(train_data):
    
#     image_path = os.path.join(config['image_root'], data['img_local_path'])
#     image = Image.open(image_path).convert('RGB')
#     image = train_transform(image)[None,:]
#     image = image.to(device)

#     c = model.generate(image,num_return_sequences=1,sample=True, num_beams=1)
#     image_cap_dict[data['img_local_path']] = c[0][0]
# Out:
#  14%|█▎        | 2198/16176 [16:29<1:44:54,  2.22it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /root/thesis/X-VLM/gen_caption_for_train.ipynb Cell 10' in <cell line: 10>()
#      <a href='vscode-notebook-cell://ssh-remote%2B172.29.64.76/root/thesis/X-VLM/gen_caption_for_train.ipynb#ch0000002vscode-remote?line=25'>26</a> image_batch = torch.stack(array)
#      <a href='vscode-notebook-cell://ssh-remote%2B172.29.64.76/root/thesis/X-VLM/gen_caption_for_train.ipynb#ch0000002vscode-remote?line=26'>27</a> image_batch = image_batch.to(device)
# ---> <a href='vscode-notebook-cell://ssh-remote%2B172.29.64.76/root/thesis/X-VLM/gen_caption_for_train.ipynb#ch0000002vscode-remote?line=28'>29</a> c = model.generate(image_batch,num_return_sequences=1,sample=True, num_beams=1)
#      <a href='vscode-notebook-cell://ssh-remote%2B172.29.64.76/root/thesis/X-VLM/gen_caption_for_train.ipynb#ch0000002vscode-remote?line=29'>30</a> image_cap_dict[keys[0]] = c[0][0]
#      <a href='vscode-notebook-cell://ssh-remote%2B172.29.64.76/root/thesis/X-VLM/gen_caption_for_train.ipynb#ch0000002vscode-remote?line=30'>31</a> image_cap_dict[keys[1]] = c[0][1]
#
# KeyboardInterrupt:

# %%
image_cap_dict
# Out:
# {'train/1.jpg': 'a person holding a cell phone in front of a table',
#  'train/2.jpg': 'a man standing in front of a crowd of people',
#  'train/0.jpg': 'a group of people walking down a street with a statue',
#  'train/8.jpg': 'a man standing in the snow with a suitcase on a street',
#  'train/9.jpg': 'a man in a business suit and police officer standing with a suitcase',
#  'train/10.jpg': 'a man walking a dog on a street',
#  'train/11.jpg': 'a group of people holding signs in a building',
#  'train/12.jpg': 'a yellow at a site with a yellow fire truck with a person',
#  'train/18.jpg': 'a group of soldiers laying in front of a helicopter',
#  'train/19.jpg': 'a group of people sitting in a street from a flooded street',
#  'train/20.jpg': 'a man wearing a suit and tie with a person',
#  'train/21.jpg': 'a group of people standing in a room',
#  'train/22.jpg': 'a man in a suit and tie standing at a podium',
#  'train/28.jpg': 'a group of people riding bikes down a road',
#  'train/29.jpg': 'a man sitting on a bench with a red tent',
#  'train/30.jpg': 'a man holding gun in front of a person holding a building',
#  'train/31.jpg': 'the man in a suit and tie standing in front of a green person',
#  'train/32.jpg': 'a man sitting at a table with a person',
#  'train/38.jpg': 'a group of people sitting on the back of a truck',
#  'train/39.jpg': 'a man in a suit and tie standing in front of a sign',
#  'train/40.jpg': 'a woman standing in front of a blue background',
#  'train/41.jpg': 'the president and other people standing in front of a podium',
#  'train/42.jpg': 'a woman sitting in a chair in a room',
#  'train/48.jpg': 'a group of people standing in front of a train',
#  'train/49.jpg': 'a group of vehicles on a city street with a windows',
#  'train/50.jpg': 'a man in a suit and tie standing in front of a microphone',
#  'train/51.jpg': 'a woman in a black suit and a tree',
#  'train/52.jpg': 'a group of individuals sitting in a meeting',
#  'train/58.jpg': 'a man standing on a boat in the ocean',
#  'train/59.jpg': 'a man and a woman standing in a room',
#  'train/60.jpg': 'a group of people walking down a street',
#  'train/61.jpg': 'a sign on the side of a fence',
#  'train/62.jpg': 'there are men standing on the field with a person with this tree',
#  'train/68.jpg': 'a man and a woman standing next to each other',
#  'train/69.jpg': 'a group of soldiers sitting in a field of person person',
#  'train/70.jpg': 'a group of people standing in front of a poster',
#  'train/71.jpg': 'a man in a suit and tie standing in a room',
#  'train/72.jpg': 'a group of men walking down a street with police officers',
#  'train/78.jpg': 'a woman wearing a brown jacket and a blue jeans',
#  'train/79.jpg': 'a group of people standing next to each other',
#  'train/80.jpg': 'a group of men standing next to a man with microphones',
#  'train/81.jpg': 'a black and white photo of a man in a suit and tie',
#  'train/82.jpg': 'a group of people standing in a group of soldiers',
#  'train/88.jpg': 'a group of police members walking down a street',
#  'train/89.jpg': 'president is sitting in a desk with two us national flags',
#  'train/90.jpg': 'two men in suits standing in front of a building',
#  'train/91.jpg': 'a man sitting at a table with a world on a screen',
#  'train/92.jpg': 'two men sitting at a table in a meeting',
#  'train/98.jpg': 'a man riding skis on top of a snow covered hill',
#  'train/99.jpg': 'a woman holding a microphone in front of a crowd of people',
#  'train/100.jpg': 'a man standing at a podium in front of a person',
#  'train/101.jpg': 'the man sitting at a table in front of the hat',
#  'train/102.jpg': 'a group of people sitting at a table with wine glasses',
#  'train/108.jpg': 'a woman sitting in a chair holding a circa',
#  'train/109.jpg': 'a group of people walking in an airport',
#  'train/110.jpg': 'a man standing in a factory with a person standing on a 7',
#  'train/111.jpg': 'a group of people sitting at a table with wine glasses',
#  'train/112.jpg': 'a man and woman standing in front of a microphone',
#  'train/118.jpg': 'two men in suits with a white candle in a everyone',
#  'train/119.jpg': 'a man standing on top of a mountain with a mountain',
#  'train/120.jpg': 'a man and a man walking with a church with a person',
#  'train/121.jpg': 'two men in between two times showing off a microphone',
#  'train/122.jpg': 'a man carrying a suitcase in front of a gate',
#  'train/128.jpg': 'two men in suits and ties standing next to each other',
#  'train/129.jpg': 'a white plate and a spoon on a red table',
#  'train/130.jpg': 'a woman holding a cup of food and person person in a field',
#  'train/131.jpg': 'a man in a suit and tie sitting on a chair',
#  'train/132.jpg': 'a group of people standing in a room with cell phones',
#  'train/138.jpg': 'a group of people standing in a room with a person',
#  'train/139.jpg': 'a group of people standing on skis in the snow',
#  'train/140.jpg': 'a person riding skis down a snow covered slope',
#  'train/141.jpg': 'a bald man in a suit and tie',
#  'train/142.jpg': 'two men walking down a street with suits and ties',
#  'train/148.jpg': 'a group of people on a raft in the water',
#  'train/149.jpg': 'a group of men walking down a street with police officers',
#  'train/150.jpg': 'a group of people standing in front of a painting',
#  'train/151.jpg': 'a group of people standing next to art on the wall',
#  'train/152.jpg': 'a man and a woman sitting on a stage with a microphone',
#  'train/158.jpg': 'a black and white photo of a group of people and a car',
#  'train/159.jpg': 'a black man sitting in a suit and red tie',
#  'train/160.jpg': 'the president standing in front of a microphone',
#  'train/161.jpg': 'a group of people standing in front of a logo',
#  'train/162.jpg': 'a man sitting at a podium in a room',
#  'train/168.jpg': 'a man standing next to a fence talking on a cell phone',
#  'train/169.jpg': 'a group of people standing next to a sign on a street',
#  'train/170.jpg': 'two men standing in front of a table',
#  'train/171.jpg': 'a group of people standing in a crowd of people',
#  'train/172.jpg': 'a man standing in a crowd of people standing with a sign',
#  'train/178.jpg': 'a woman standing in front of a person at a flag person behind a microphone',
#  'train/179.jpg': 'a group of people standing next to a statue',
#  'train/180.jpg': 'two signs on the side of a dirt road',
#  'train/181.jpg': 'a woman sitting on a stage with a tv',
#  'train/182.jpg': 'a man standing in front of a gold coins on a podium',
#  'train/188.jpg': 'a group of men in front of a crowd of people',
#  'train/189.jpg': 'a group of people standing on a street with signs',
#  'train/190.jpg': 'a woman in a suit and tie standing in front of national flags',
#  'train/191.jpg': 'a gray man wearing a suit and tie in front of a table',
#  'train/192.jpg': 'a man standing at a podium in front of a room',
#  'train/198.jpg': 'a fall in the ice on a river and a city',
#  'train/199.jpg': 'a woman standing at a podium in a room',
#  'train/200.jpg': 'a man in a suit and tie standing in a room',
#  'train/201.jpg': 'a pink sign on the side of a tall building',
#  'train/202.jpg': 'a dog walking in front of a building at night',
#  'train/208.jpg': 'a group of men walking through a room with a chandeliers',
#  'train/209.jpg': 'a group of soldiers standing on top of a keeping',
#  'train/210.jpg': 'a spring spring in a fence with flowers and a person',
#  'train/211.jpg': 'a man standing at a podium with microphones',
#  'train/212.jpg': 'a group of people sitting in a room with microphones',
#  'train/218.jpg': 'a woman holding a cell phone in her hand',
#  'train/219.jpg': 'a group of people holding a sign in front of a building',
#  'train/220.jpg': 'a man sitting at a podium in front of a person',
#  'train/221.jpg': 'a man and a woman standing in front of a statue',
#  'train/222.jpg': 'a man and a woman standing next to each other',
#  'train/228.jpg': 'two men sitting in a chair in front of art',
#  'train/229.jpg': 'a group of men standing in front of a door',
#  'train/230.jpg': 'a man standing in front of a picture of a man',
#  'train/231.jpg': 'a thermo on top of a window',
#  'train/232.jpg': 'a man sitting in a car reading a newspaper',
#  'train/238.jpg': 'a group of people standing on top of a ramp with flags',
#  'train/239.jpg': 'a kangaroo standing in front of a house with a person',
#  'train/240.jpg': 'a man sitting at a table with a person in the background',
#  'train/241.jpg': 'a group of army men standing in front of a ceremony',
#  'train/242.jpg': 'a group of soldiers standing on a street with a back concept of smoke',
#  'train/248.jpg': 'a group of people reading a book in a living room',
#  'train/249.jpg': 'a group of soldiers standing in a street',
#  'train/250.jpg': 'the president sitting at a table in front of a table',
#  'train/251.jpg': 'two ships in the water next to the ocean',
#  'train/252.jpg': 'a clouds of water and a fire in the sky',
#  'train/258.jpg': 'a man standing in front of a microphone',
#  'train/259.jpg': 'a man standing on a street with a fire in the road',
#  'train/260.jpg': 'a group of people standing around a cake',
#  'train/261.jpg': 'a group of people standing in a room with men',
#  'train/262.jpg': 'a group of people standing in the back of a truck',
#  'train/268.jpg': 'a home with a car sitting in front of a burnt roof',
#  'train/269.jpg': 'a group of men and people standing in front of a podium',
#  'train/270.jpg': 'a groups of people sitting on the street holding signs',
#  'train/271.jpg': 'a man wearing a hat on top of a guy in a white shirt and a person with a cell phone',
#  'train/272.jpg': 'a young boy sitting in front of a computer screen',
#  'train/278.jpg': 'a group of people standing in a room with a person',
#  'train/279.jpg': 'a man and a woman standing next to each other',
#  'train/280.jpg': 'a group of people sitting on a wall',
#  'train/281.jpg': 'a sign in front of a building with a parking lot',
#  'train/282.jpg': 'a man holding a guitar in front of a table',
#  'train/288.jpg': 'a man sitting in a car reading a newspaper',
#  'train/289.jpg': 'a row of lipsticks in a display stock with a sale for the person',
#  'train/290.jpg': 'a group of people standing in front of a military truck with a ziaione is on a street',
#  'train/291.jpg': 'two men standing in front of a blue building with a suit and tie',
#  'train/292.jpg': 'a group of people standing on top of a building with kites',
#  'train/298.jpg': 'a man sitting at a podium in front of a black table',
#  'train/299.jpg': 'two men in suits standing in front of a microphone',
#  'train/300.jpg': 'two men walking down awalk in a pink suit',
#  'train/301.jpg': 'a woman laying on a bed with a person',
#  'train/302.jpg': 'a group of people standing on a couch with a name sign',
#  'train/308.jpg': 'a man sitting in a car with a person in the front',
#  'train/309.jpg': 'a group of people standing on top of a screen and a table',
#  'train/310.jpg': 'a woman sitting in front of a fireplace with a fire',
#  'train/311.jpg': 'a man wearing glasses and a blue shirt and a microphone',
#  'train/312.jpg': 'a man sitting on a suitcase on a road with a fire',
#  'train/318.jpg': 'a yellow commemorate on the ground in a earthy field',
#  'train/319.jpg': 'a man in a jacket and a tie walking down a street',
#  'train/320.jpg': 'a man sitting in a chair next to a suitcase',
#  'train/321.jpg': 'a military man throwing a military guy in a back of a amazing of fire',
#  'train/322.jpg': 'a fire is is sitting on the side of a street',
#  'train/328.jpg': 'a view of a group of people standing in a city',
#  'train/329.jpg': 'a firefighter standing in the woods with a fire truck',
#  'train/330.jpg': 'a man sitting on top of a truck in the street',
#  'train/331.jpg': 'a businessman standing in front of a table with flags',
#  'train/332.jpg': 'a face in the air with banner in a crowd of people',
#  'train/338.jpg': 'a group of people standing in front of a street',
#  'train/339.jpg': 'a man standing at a podium in front of a table',
#  'train/340.jpg': 'two military men sitting on top of a helicopter person',
#  'train/341.jpg': 'a group of people walking on the tarmac at an airport',
#  'train/342.jpg': 'a man sitting in front of a picture of a black suit and tie',
#  'train/348.jpg': 'a woman holding a microphone in front of a table',
#  'train/349.jpg': 'a man standing at a podium in a room',
#  'train/350.jpg': 'a screen of a movie person on top of a keyboard',
#  'train/351.jpg': 'a group of people holding the top of a banner',
#  'train/352.jpg': 'a remains of an applicator sitting on the side of a wall',
#  'train/358.jpg': 'a group of people walking down a street with a flag',
#  'train/359.jpg': 'a group of people standing on a patch of camping organs',
#  'train/360.jpg': 'a group of people walking in front of a train',
#  'train/361.jpg': 'two men standing next to each other in a person',
#  'train/362.jpg': 'the president and a guy sitting in front of each other',
#  'train/368.jpg': 'a woman standing at a microphone in front of a podium',
#  'train/369.jpg': 'a man cutting a floral flowers in an airport',
#  'train/370.jpg': 'a man standing in front of a pile of rubble and person standing in front of a building',
#  'train/371.jpg': 'a group of people standing in front of a store',
#  'train/372.jpg': 'a group of women standing in front of a building',
#  'train/378.jpg': 'a man standing in front of a yellow bus with a county as a person',
#  'train/379.jpg': 'a group of people sitting in front of a bus',
#  'train/380.jpg': 'a woman sitting at a table with a cell phone',
#  'train/381.jpg': 'a row of chairs and tables on a room with a table',
#  'train/382.jpg': 'a group of people walking down an escalator',
#  'train/388.jpg': 'a woman walking down the street with a wall with a flag',
#  'train/389.jpg': 'a man standing next to a bunch of roses and flowers',
#  'train/390.jpg': 'a view of a building sitting on the side of a body of water',
#  'train/391.jpg': 'a woman sitting in a chair in a room',
#  'train/392.jpg': 'a group of men holding a pair of scissors',
#  'train/398.jpg': 'a group of people standing on top of a building',
#  'train/399.jpg': 'a group of men standing in a room with a flag',
#  'train/400.jpg': 'a view of a building on the side of a land',
#  'train/401.jpg': 'a group of people standing next to a fire truck',
#  'train/402.jpg': 'a group of people holding signs in a street',
#  'train/408.jpg': 'a groups of people waving a peace sign in the air',
#  'train/409.jpg': 'two men sitting in front of the chairs in front of the room',
#  'train/410.jpg': 'a woman in a purple dress and a man walking in the street',
#  'train/411.jpg': 'a kangaroo standing in front of a building with a red fire concept',
#  'train/412.jpg': 'a group of people standing around a table',
#  'train/418.jpg': 'a group of people flying kites on the beach',
#  'train/419.jpg': 'a group of men standing in front of a podium',
#  'train/420.jpg': 'a group of people riding motorcycles in a street',
#  'train/421.jpg': 'a group of soldiers walking down a city street',
#  'train/422.jpg': 'a man standing in a room with a microphone',
#  'train/428.jpg': 'a man sitting at a table with a glasses',
#  'train/429.jpg': 'a large turtle laying on the ground',
#  'train/430.jpg': 'a group of people standing in front of a traffic light',
#  'train/431.jpg': 'two men standing in front of a glass building',
#  'train/432.jpg': 'a group of people walking down a aren in front of a mountain',
#  'train/438.jpg': 'a television with two women on top of it',
#  'train/439.jpg': 'a group of people standing next to each other',
#  'train/440.jpg': 'a group of people standing on a stage',
#  'train/441.png': 'a man in a suit and tie standing on a desk',
#  'train/442.jpg': 'a man with a shirt and a tie on a couch',
#  'train/448.jpg': 'the president standing at a podium in front of a group of person in a crowd',
#  'train/449.jpg': 'a group of people laying on the street',
#  'train/450.jpg': 'a group of people standing in front of the lincoln park in a city',
#  'train/451.jpg': 'a view of a group of individuals standing in a building',
#  'train/452.jpg': 'a group of men standing on a stage',
#  'train/458.jpg': 'a group of people walking in a hall',
#  'train/459.jpg': 'a group of people walking in a hall',
#  'train/460.jpg': 'a truck on the side of a field with a field',
#  'train/461.jpg': 'a group of men standing in front of a table',
#  'train/462.jpg': 'a taken of a person in a glass dome on a building',
#  'train/468.jpg': 'a crowd of people standing in a building with person on a poster',
#  'train/469.jpg': 'a group of people holding candles on a stage with lit candles',
#  'train/470.jpg': 'a train is sitting on the top of a fence',
#  'train/471.jpg': 'a group of police officers standing next to a fire truck',
#  'train/472.jpg': 'a man standing at a podium with a microphone',
#  'train/478.jpg': 'a group of people holding signs in a stadium',
#  'train/479.jpg': 'a group of men standing on a city street with business clothing',
#  'train/480.jpg': 'a man sitting in front of a microphone',
#  'train/481.jpg': 'a man sitting at a podium in front of a microphone',
#  'train/482.jpg': 'a group of cars sitting in front of a demolished building',
#  'train/488.jpg': 'a group of people walking down a street',
#  'train/489.jpg': 'a red and white airplane flying in the sky',
#  'train/490.jpg': 'a view of a flooded street with houses and houses',
#  'train/491.jpg': 'a man standing next to a wall with a sign',
#  'train/492.jpg': 'a man in a protective suit walking down a stairs',
#  'train/498.jpg': 'a group of people standing in a crowd of people',
#  'train/499.jpg': 'a man and a woman standing in a blue shirt',
#  'train/500.jpg': 'two elderly people sitting on blue chairs in a event',
#  'train/501.jpg': 'a black and white photo of a man sitting at a table with a map',
#  'train/502.jpg': 'a football player is standing on a field',
#  'train/508.jpg': 'two men sitting in a seat in a room with a red tie',
#  'train/509.jpg': 'a group of people sitting in front of a audience',
#  'train/510.jpg': 'a group of people standing in a train',
#  'train/511.jpg': 'a woman sitting on the subway train with a person',
#  'train/512.jpg': 'a group of people standing around a table',
#  'train/518.jpg': 'a group of people standing in a room with cell phones',
#  'train/519.jpg': 'a view of a room with a person sitting on a table',
#  'train/520.jpg': 'a group of people sitting in a auditorium',
#  'train/521.jpg': 'two men standing on a black new and white of him in a suit',
#  'train/522.jpg': 'a group of people sitting in chairs in a wall',
#  'train/528.jpg': 'a group of people sitting at a table',
#  'train/529.jpg': 'a group of people walking in a museum',
#  'train/530.jpg': 'a view of a city with buildings and skyscrapers',
#  'train/531.jpg': 'a group of people standing in a shopping district',
#  'train/532.jpg': 'a fire h free concept in the distance of a forest',
#  'train/538.jpg': 'a group of men in suits standing in a room',
#  'train/539.jpg': 'a black and white photo of a man sitting at a table with a business card',
#  'train/540.jpg': 'two men standing in front of a podium',
#  'train/541.jpg': 'the president standing in front of a podium',
#  'train/542.jpg': 'two men walking in front of a car with a luggage',
#  'train/548.jpg': 'a man walking down a platform next to a statue',
#  'train/549.jpg': 'a man holding signs in front of a building',
#  'train/550.jpg': 'a person holding a your hand in the sky with a star in a pattern',
#  'train/551.jpg': 'a man standing in front of a podium with a person',
#  'train/552.jpg': 'the president walking in a field with a red tie',
#  'train/558.jpg': 'a close up of a man wearing a suit and tie',
#  'train/559.jpg': 'a man standing in front of a crowd of people standing on a stage',
#  'train/560.jpg': 'a man standing in front of a microphone',
#  'train/561.jpg': 'a group of people flying their arms in the air',
#  'train/562.jpg': 'a man in a suit and tie sitting in a table',
#  'train/568.jpg': 'the president standing in front of a microphone',
#  'train/569.jpg': 'a man standing at a podium in front of a man in a military uniform',
#  'train/570.jpg': 'a group of people standing standing around a table',
#  'train/571.jpg': 'two men walking down a hallway with a person',
#  'train/572.jpg': 'a group of people wearing face masks in a meeting',
#  'train/578.jpg': 'a dish of food in a pan on a table',
#  'train/579.jpg': 'a group of people standing in front of a body of water',
#  'train/580.jpg': 'a man sitting at a desk in a room with a person',
#  'train/581.jpg': 'a group of people standing in a church',
#  'train/582.jpg': 'a man standing in front of a red building',
#  'train/588.jpg': 'a group of soldiers walking down a dirt road',
#  'train/589.jpg': 'a man sitting in front of a microphone',
#  'train/590.jpg': 'a group of people standing in a casino',
#  'train/591.jpg': 'a man in a suit and tie standing in front of a window',
#  'train/592.jpg': 'a man sitting in front of a person in front of a person sitting in a room',
#  'train/598.jpg': 'a group of people with flag and fire can of fire',
#  'train/599.jpg': 'a man standing in front of a podium',
#  'train/600.jpg': 'a man sitting in front of a microphone',
#  'train/601.jpg': 'a group of cars in a factory',
#  'train/602.jpg': 'two men sitting at a table with microphones',
#  'train/608.jpg': 'a man sitting at a table with a famous person sitting in front of a microphone',
#  'train/609.jpg': 'a man standing at a podium in front of a person',
#  'train/610.jpg': 'a man sitting at a podium with a microphone',
#  'train/611.jpg': 'a group of people walking down a street with masks',
#  'train/612.jpg': 'a group of men sitting at a table',
#  'train/618.jpg': 'a group of people holding signs in the street',
#  'train/619.jpg': 'a woman wearing a hat on top of a field',
#  'train/620.jpg': 'a crowd of people gathered in a mountain with a building',
#  'train/621.jpg': 'two men standing next to each other hold a picture',
#  'train/622.jpg': 'two men standing in a factory with a red mansion in the air',
#  'train/628.jpg': 'two men standing on steps in front of a building',
#  'train/629.jpg': 'a man standing in front of a building with a cell phone',
#  'train/630.jpg': 'a group of people standing around a room with cameras',
#  'train/631.jpg': 'a group of people standing in a room with signs',
#  'train/632.jpg': 'a man standing in front of a water at a city at night',
#  'train/638.jpg': 'a man standing at a podium in front of a crowd of people',
#  'train/639.jpg': 'a man walking down the stairs in front of a building',
#  'train/640.jpg': 'a group of people holding signs in a park originates with flags',
#  'train/641.jpg': 'two men standing next to each other with a cell phone',
#  'train/642.jpg': 'a woman holding a flag in the street',
#  'train/648.jpg': 'a group of people sitting in front of a stage',
#  'train/649.jpg': 'a large building with a man on a balcony with a poster',
#  'train/650.jpg': 'a man standing in front of a crowd of people',
#  'train/651.jpg': 'a group of people standing in front of all of the american flag',
#  'train/652.jpg': 'a building with a sign on the side of it',
#  'train/658.jpg': 'a group of men walking through a crowd of people',
#  'train/659.jpg': 'a man wearing a red hat with a person in the distance',
#  'train/660.jpg': 'a man with a blue shirt and a person but with a flowers',
#  'train/661.jpg': 'a group of people holding a red and white flag',
#  'train/662.jpg': 'a group of women standing in front of a building with signs',
#  'train/668.jpg': 'a group of people holding signs in a room',
#  'train/669.jpg': 'a group of american football players holding were the trophy',
#  'train/670.jpg': 'a group of men standing in front of a building with a mask',
#  'train/671.jpg': 'a man sitting in the back of a orange car with a dog',
#  'train/672.jpg': 'a group of men holding a winr a trophy in the air',
#  'train/678.jpg': 'a group of men walking in front of military men in red uniform',
#  'train/679.jpg': 'a man standing in front of a conference where a microphone',
#  'train/680.jpg': 'a car parked in front of a building with a water tower',
#  'train/681.jpg': 'a man standing in front of a usa flag',
#  'train/682.jpg': 'a group of people standing around a table with cell phones',
#  'train/688.jpg': 'a man and a woman standing next to each other',
#  'train/689.jpg': 'a clock on the side of a building',
#  'train/690.jpg': 'a woman standing in front of a black dress and a chair',
#  'train/691.jpg': 'a group of men standing at a podium',
#  'train/692.jpg': 'a group of men sitting at a table',
#  'train/698.jpg': 'a black and white photo of a group of people standing in a office',
#  'train/699.jpg': 'a presidentton in a suit and tie is giving the air in his hand',
#  'train/700.jpg': 'a woman standing in front of a group of people holding a microphone',
#  'train/701.jpg': 'a black and white photo of a man in a suit and tie',
#  'train/702.jpg': 'a man in a suit and tie sitting in a table',
#  'train/708.jpg': 'a group of people holding a sign in the air',
#  'train/709.jpg': 'a group of people holding yoga in a room',
#  'train/710.jpg': 'a woman standing in front of microphones in a street',
#  'train/711.jpg': 'a group of people holding signs in a crowd of people',
#  'train/712.jpg': 'two people sitting on chairs in a room',
#  'train/718.jpg': 'a group of people holding signs in the air',
#  'train/719.jpg': 'a man standing in front of a the building with a building',
#  'train/720.jpg': 'two men standing next to each other in front of a black background',
#  'train/721.jpg': 'a white building with a clock on the top of it',
#  'train/722.jpg': 'a man and woman standing in a hall',
#  'train/728.jpg': 'a man sitting in front of a podium',
#  'train/729.jpg': 'a group of people sitting at a table',
#  'train/730.jpg': 'a group of people holding signs on a street',
#  'train/731.jpg': 'a woman standing in front of a microphone',
#  'train/732.jpg': 'a group of people in a car on a ferris wheel',
#  'train/738.jpg': 'a woman holding a microphone in front of a table',
#  'train/739.jpg': 'a bathroom with a toilet and a sink',
#  'train/740.jpg': 'a group of people sitting around a table',
#  'train/741.jpg': 'a woman getting her hair off of a man on a cell phone',
#  'train/742.jpg': 'a man sitting on a table in front of a bunch of shoes',
#  'train/748.jpg': 'a man in a suit and tie standing at a podium',
#  'train/749.jpg': 'a man and a woman standing in front of a crowd',
#  'train/750.jpg': 'a woman sitting at a desk with a laptop computer',
#  'train/751.jpg': 'a group of people standing in front of a subway train',
#  'train/752.jpg': 'the guy standing on a stage with a crowd of people',
#  'train/758.jpg': 'a sign on the side of a luggage with a sign',
#  'train/759.jpg': 'a group of people standing in front of a vast weight in a build',
#  'train/760.jpg': 'two men standing next to each other in front of a door',
#  'train/761.jpg': 'a woman standing in the snow on a cell phone',
#  'train/762.jpg': 'a group of people sitting in front of cell phones',
#  'train/768.jpg': 'a group of people holding signs on a street',
#  'train/769.jpg': 'a man standing at a desk with a microphone',
#  'train/770.jpg': 'a group of people standing in a classroom',
#  'train/771.jpg': 'a woman and a young boy standing around a table with a orange person',
#  'train/772.jpg': 'a group of people standing around a room',
#  'train/778.jpg': 'a woman standing behind a microphone on a table',
#  'train/779.jpg': 'a man and two women standing at a podium',
#  'train/780.jpg': 'a man in a suit and tie standing in front of a black backdrop',
#  'train/781.jpg': 'a man standing on the stage with a microphone',
#  'train/782.jpg': 'a group of people taking pictures of each other',
#  'train/788.jpg': 'a group of people walking down a street with a sign',
#  'train/789.jpg': 'a group of people standing next to a tree with art on a tree',
#  'train/790.jpg': 'a black man wearing a suit and tie',
#  'train/791.jpg': 'a view of a city street with cars and a bus',
#  'train/792.jpg': 'the back of the president standing at a podium with a mezzan person',
#  'train/798.jpg': 'two women standing next to each other in a train',
#  'train/799.jpg': 'two women sitting at a table with a laptop computer',
#  'train/800.jpg': 'a man in a suit and tie standing in front of a room',
#  'train/801.jpg': 'a man sitting on top of a room with a balcony',
#  'train/802.jpg': 'a man standing in front of a microphone',
#  'train/808.jpg': 'a woman standing at a podium with a microphone',
#  'train/809.jpg': 'a group of people standing in front of a flag',
#  'train/810.jpg': 'two men in a vehicle with a person in the back',
#  'train/811.jpg': 'a sign on the side of a door with balloons',
#  'train/812.jpg': 'a man in a suit and tie giving a microphone',
#  'train/818.jpg': 'a group of men walking down a hall',
#  'train/819.jpg': 'a man and two women standing in front of a car',
#  'train/820.jpg': 'a group of people holding signs in a crowd',
#  'train/821.jpg': 'the man and a woman standing at a podium',
#  'train/822.jpg': 'a man standing on a stage with a microphone',
#  'train/828.jpg': 'a man standing in front of a podium with a person in front of a table',
#  'train/829.jpg': 'two men standing next to each other in front of a screen',
#  'train/830.jpg': 'a man sitting in the back of a car',
#  'train/831.jpg': 'a woman standing in front of a flag',
#  'train/832.png': 'a black and white photo of a woman in a dress',
#  'train/838.jpg': 'a group of people walking down a city street',
#  'train/839.jpg': 'a man with a microphone in front of a table',
#  'train/840.jpg': 'the president standing at a podium with head of the microphone',
#  'train/841.jpg': 'a man holding a baseball ball in a field',
#  'train/842.jpg': 'a close up of an man wearing a suit and tie',
#  'train/848.jpg': 'a reception desk in a room with a picture of a man',
#  'train/849.jpg': 'a man in a suit and tie standing in a room',
#  'train/850.jpg': 'a group of people standing in a building',
#  'train/851.jpg': 'a man sitting in a chair in a room with a bike',
#  'train/852.jpg': 'a woman sitting at a table with a red wall',
#  'train/858.jpg': 'two men sitting in front of a chair',
#  'train/859.jpg': 'a black and white photo of a man holding a package',
#  'train/860.jpg': 'a man in a suit and tie standing in front of a building',
#  'train/861.jpg': 'a man holding a plate of button a cake on a table',
#  'train/862.jpg': 'a group of people standing in a room',
#  'train/868.jpg': 'a group of people standing next to each other',
#  'train/869.jpg': 'a man standing in front of a group of people with sign',
#  'train/870.jpg': 'a black and white photo of the capitol building',
#  'train/871.jpg': 'a man holding a cell phone in front of a crowd',
#  'train/872.jpg': 'two people are shown next to each other in suits and glasses',
#  'train/878.jpg': 'a man in a suit and tie standing in front of a building',
#  'train/879.jpg': 'a man standing in front of a proceed with a right hand on a fence',
#  'train/880.jpg': 'a group of people sitting on a bench',
#  'train/881.jpg': 'a group of people walking down a street with signs',
#  'train/882.jpg': 'a woman in a camouflage jacket and a tie standing in the snow',
#  'train/888.jpg': 'a man standing on a sunday in front of a church',
#  'train/889.jpg': 'a man standing in front of a bus',
#  'train/890.jpg': 'a man sitting in a suit and glasses sitting at a microphone',
#  'train/891.jpg': 'a woman sitting at a table with a microphone',
#  'train/892.jpg': 'a group of people riding a skateboard in a street',
#  'train/898.jpg': 'a group of people standing in front of a famous hall with a chandeliers',
#  'train/899.jpg': 'a man walking in front of a follow up company building',
#  'train/900.jpg': 'a group of people standing in a group of people',
#  'train/901.jpg': 'a woman cutting a mans hair in a salon',
#  'train/902.jpg': 'two women sitting at a table with microphones',
#  'train/908.jpg': 'a group of people standing in a room with a flag',
#  'train/909.jpg': 'a man standing in front of a person in a table',
#  'train/910.jpg': 'a man sitting on top of a man in the crowd',
#  'train/911.jpg': 'a woman standing in front of a city street with a fence',
#  'train/912.jpg': 'a black and white photo of a man talkin a microphone',
#  'train/918.jpg': 'a woman standing in front of a desk with a laptop',
#  'train/919.jpg': 'a group of people standing in a room',
#  'train/920.jpg': 'a woman standing in front of a room with empty chairs',
#  'train/921.jpg': 'a man and a woman walking down a hallway',
#  'train/922.jpg': 'a group of people holding signs in a street',
#  'train/928.jpg': 'a man in a suit and tie in front of a shows his hand',
#  'train/929.jpg': 'a man sitting in front of a circle of candles',
#  'train/930.jpg': 'a man in a suit and tie standing in the snow',
#  'train/931.jpg': 'a woman standing on a stage holding a microphone',
#  'train/932.jpg': 'a group of people standing in front of a truck',
#  'train/938.jpg': 'a group of people standing in a room playing song with a guitar',
#  'train/939.jpg': 'a group of people standing around a piles of flowers',
#  'train/940.jpg': 'a man standing in the snow under an umbrella',
#  'train/941.jpg': 'a man and a woman standing in front of a painting',
#  'train/942.jpg': 'a group of men standing next to each other',
#  'train/948.jpg': 'a man wearing a blue suit and a watch',
#  'train/949.jpg': 'a man holding a red hat on a person in a crowd',
#  'train/950.jpg': 'a group of people sitting in a room with american flags',
#  'train/951.jpg': 'a woman standing in front of a desk with a microphone',
#  'train/952.jpg': 'a man standing at a podium in a room',
#  'train/958.jpg': 'two men standing next to each other in a suit and tie',
#  'train/959.jpg': 'a man sitting in a chair in a stop sign',
#  'train/960.jpg': 'a group of people walking down a street',
#  'train/961.jpg': 'a man and a woman standing next to each other',
#  'train/962.jpg': 'a man standing in a tunnel with a skateboard',
#  'train/968.jpg': 'two soldiers walking in front of each other',
#  'train/969.jpg': 'a man sitting at a table with a glass of soda',
#  'train/970.jpg': 'a man holding a hin a laptop computer in a room',
#  'train/971.jpg': 'a woman holding a microphone in front of a flag',
#  'train/972.jpg': 'a woman holding a sign in front of a street',
#  'train/978.jpg': 'a group of people standing at a counter with a box',
#  'train/979.jpg': 'a man walking in the rain on a street with signs',
#  'train/980.jpg': 'a woman walking down a hall with a camera',
#  'train/981.jpg': 'a man and a woman standing next to each other',
#  'train/982.jpg': 'a group of people standing on a city street with a traffic light',
#  'train/988.jpg': 'a group of people walks down the steps',
#  'train/989.jpg': 'two people holding signs in front of a person holdingperson',
#  'train/990.jpg': 'a bar with a s person and a person on a credit card',
#  'train/991.jpg': 'a group of people walking in front of a clock tower',
#  'train/992.jpg': 'a group of people sitting at a desk with a dog',
#  'train/998.jpg': 'a desk with a refrigerator and a table with a picture',
#  'train/999.jpg': 'a woman standing next to a man with a person',
#  'train/1000.jpg': 'two men sitting in chairs in a room',
#  'train/1001.jpg': 'a man standing at a podium in front of a tv',
#  'train/1002.jpg': 'a group of people standing in a crowd of people',
#  'train/1008.jpg': 'the president sitting at a podium and holding a microphone',
#  'train/1009.jpg': 'a man sitting at a desk in a room',
#  'train/1010.jpg': 'a person walking down a snow covered road with a snow laden tree',
#  'train/1011.jpg': 'two men sitting in front of a podium',
#  'train/1012.jpg': 'a photo of a man standing in front of a person holding a microphone',
#  'train/1018.jpg': 'a man and a woman standing on a dance floor',
#  'train/1019.jpg': 'a group of people holding signs in front of a building',
#  'train/1020.jpg': 'a group of people standing on a stage with a person',
#  'train/1021.jpg': 'a train traveling down the tracks in a city',
#  'train/1022.jpg': 'a man standing in front of a stage with a microphone',
#  'train/1028.jpg': 'a man in a suit and tie standing in front of a table',
#  'train/1029.jpg': 'a group of people walking in front of a helicopter',
#  'train/1030.jpg': 'a group of papers on top of a table',
#  'train/1031.jpg': 'a group of people standing in a room with cell phones',
#  'train/1032.jpg': 'a man standing in front of a television',
#  'train/1038.jpg': 'a group of men walking down a city street',
#  'train/1039.jpg': 'a woman standing in front of a flag with a nice person',
#  'train/1040.jpg': 'a city street with buildings and a car on a street',
#  'train/1041.jpg': 'a man sitting at a table with a gestures in a television',
#  'train/1042.jpg': 'a man sitting at a desk in a room',
#  'train/1048.jpg': 'a woman standing on a stage with a person in front of a crowd',
#  'train/1049.jpg': 'a man standing in front of a group of people holding signs',
#  'train/1050.jpg': 'a group of people standing in front of a bull with a construction vehicle',
#  'train/1051.jpg': 'a group of banners of face of president person on a building',
#  'train/1052.jpg': 'a man sitting at a table with a microphone',
#  'train/1058.jpg': 'a man walking in a field with a frisbee',
#  'train/1059.jpg': 'a woman sitting on a table with a sign',
#  'train/1060.jpg': 'a group of men walking through an airport',
#  'train/1061.jpg': 'a man standing in front of a blue shirt and pants',
#  'train/1062.jpg': 'a woman sitting at a table with a person',
#  'train/1068.jpg': 'a woman standing on a table with a group of papers',
#  'train/1069.jpg': 'a group of people riding skateboards in a street',
#  'train/1070.jpg': 'a street with cars on the side of a building',
#  'train/1071.jpg': 'a group of people sitting on the back of a truck',
#  'train/1072.jpg': 'a group of people sitting on top of a window',
#  'train/1078.jpg': 'a man and a woman standing next to each other holding a religious eastery',
#  'train/1079.jpg': 'a man with brown eyes looking straight to the left',
#  'train/1080.jpg': 'a man sitting on a podium with a person in front of a crowd',
#  'train/1081.jpg': 'a man standing in front of a building with a clock tower',
#  'train/1082.jpg': 'a man in a suit and tie sitting at a table',
#  'train/1088.jpg': 'a wall with graffiti on it on the side of a street',
#  'train/1089.jpg': 'a woman standing in front of a building',
#  'train/1090.jpg': 'a man walking across a street with a car',
#  'train/1091.jpg': 'a group of people walking down a train station',
#  'train/1092.jpg': 'a woman sitting in a room looking out of a window',
#  'train/1098.jpg': 'a group of people standing in a room with yellow chairs',
#  'train/1099.jpg': 'a man laying on a towel on the water',
#  'train/1100.jpg': 'a close up of a man wearing a suit and a tie',
#  'train/1101.jpg': 'a man with a microphone on top of a table',
#  'train/1102.jpg': 'the police officer and the man walking down a street',
#  'train/1108.jpg': 'a woman holding a tattoo of a person on her arm',
#  'train/1109.jpg': 'a man in a suit and tie standing in front of a building',
#  'train/1110.jpg': 'a group of people standing in front of a building',
#  'train/1111.jpg': 'a group of people standing in a building',
#  'train/1112.jpg': 'a man standing in front of a microphone',
#  'train/1118.jpg': 'a group of lines of electric lines in a field',
#  'train/1119.jpg': 'a man walking down a city street wearing a hat',
#  'train/1120.jpg': 'a group of men standing around a table with food',
#  'train/1121.jpg': 'a group of men standing in front of a microphone',
#  'train/1122.jpg': 'a man in a suit and tie waving in front of a brick building',
#  'train/1128.jpg': 'a man standing at a podium with a microphone',
#  'train/1129.jpg': 'a group of people sitting in chairs in a room',
#  'train/1130.jpg': 'a man in a shirt and a watch on a yellow background',
#  'train/1131.jpg': 'a man in a blue suit and a person in front of a crowd of people',
#  'train/1132.jpg': 'a man standing on top of a bar',
#  'train/1138.jpg': 'a man wearing a suit and blue tie standing under an umbrella',
#  'train/1139.jpg': 'an almost on the side of a space shuttle eyeinging in the air',
#  'train/1140.jpg': 'a man sitting in front of a flag',
#  'train/1141.jpg': 'a group of people sitting in front of a building with flag',
#  'train/1142.jpg': 'a man and woman standing next to each other in a room with laptops',
#  'train/1148.jpg': 'a group of children standing on a stage with a person',
#  'train/1149.jpg': 'a group of people standing in a room with people',
#  'train/1150.jpg': 'a man standing in front of a bathroom with a mirror',
#  'train/1151.jpg': 'two men standing in front of a table with a laptop',
#  'train/1152.jpg': 'a woman standing down with a cell phone',
#  'train/1158.jpg': 'a group of people standing around a street',
#  'train/1159.jpg': 'a group of people standing around with bottles of wine',
#  'train/1160.jpg': 'a group of people holding signs in the snow',
#  'train/1161.jpg': 'a man standing in front of a window of luggage',
#  'train/1162.jpg': 'a man holding a protest sign on the street',
#  'train/1168.jpg': 'a white car parked in front of a person in a car',
#  'train/1169.jpg': 'the president sitting in front of a official room',
#  'train/1170.jpg': 'a woman standing on a city street with a building',
#  'train/1171.jpg': 'a group of people sitting in a living room',
#  'train/1172.jpg': 'a woman sitting on a chair in a living room',
#  'train/1178.jpg': 'this is a man standing at a podium',
#  'train/1179.jpg': 'two men sitting on a chair in front of a room',
#  'train/1180.jpg': 'two men standing in front of one person in a suit',
#  'train/1181.jpg': 'a woman sitting on the stairs in front of a building',
#  'train/1182.jpg': 'a group of men sitting on a table with signs',
#  'train/1188.jpg': 'a group of people standing on a green grass with a frisbee',
#  'train/1189.jpg': 'a man in a suit and a person standing on a boat',
#  'train/1190.jpg': 'a woman standing in front of a usa flag',
#  'train/1191.jpg': 'a group of men standing in front of a speech podium',
#  'train/1192.jpg': 'a of a house with a garage and a person',
#  'train/1198.jpg': 'a group of men walking down a room with cell phones',
#  'train/1199.jpg': 'a man in a suit and tie walking down a crowd of people',
#  'train/1200.jpg': 'two train cars on the tracks with a body of water',
#  'train/1201.jpg': 'a group of people standing in front of a man standing in a room',
#  'train/1202.jpg': 'a group of people standing on a gym with white chairs',
#  'train/1208.jpg': 'a man in a suit and tie standing in front of a door',
#  'train/1209.jpg': 'a group of signs on the side of a street',
#  'train/1210.jpg': 'a group of people walking down a street',
#  'train/1211.jpg': 'a man holding a picture of himself in the snow',
#  'train/1212.jpg': 'a groups of people walking down a street with east london pig',
#  'train/1218.jpg': 'a man wearing glasses and a suit and tie',
#  'train/1219.jpg': 'a group of women taking a picture of a bird',
#  'train/1220.jpg': 'a group of people standing in front of a church',
#  'train/1221.jpg': 'a close up of a man wearing glasses',
#  'train/1222.jpg': 'a man in a blue suit and glasses holding a laptop computer',
#  'train/1228.jpg': 'a man standing in front of a group of hands in a microphone',
#  'train/1229.jpg': 'a man in a suit and a tie standing in a church',
#  'train/1230.jpg': 'a man sitting on a couch in a room',
#  'train/1231.jpg': 'a man in a suit and tie standing in front of a microphone',
#  'train/1232.jpg': 'a view of a city street with cars and buses',
#  'train/1238.jpg': 'a army person standing in a field with a gun',
#  'train/1239.jpg': 'a map of the us map on top of a bed',
#  'train/1240.jpg': 'a group of people standing around a table with signs',
#  'train/1241.jpg': 'a wooden cabin sitting in the sand in a field',
#  'train/1242.jpg': 'a woman standing in front of a door with a file on a porch',
#  'train/1248.jpg': 'a picture of a man in front of a person with a your or person person person in front of a text on a poster',
#  'train/1249.jpg': 'two men in suits and a red tie walking in a room',
#  'train/1250.jpg': 'a tall building with a sign in front of it',
#  'train/1251.jpg': 'a beautiful image of a crowd of people on a street',
#  'train/1252.jpg': 'a man standing on a field with a black jacket',
#  'train/1258.jpg': 'a woman standing on top of a audience of people',
#  'train/1259.jpg': 'a man and a woman standing in front of an airport',
#  'train/1260.jpg': 'a man in a suit and tie standing in a room',
#  'train/1261.jpg': 'a woman standing at a table with a cake with a fur coat',
#  'train/1262.jpg': 'the president standing in front of a microphone',
#  'train/1268.jpg': 'a woman standing on a wall with a sign',
#  'train/1269.jpg': 'two men standing on a street with a flag',
#  'train/1270.jpg': 'a man sitting at a table with a microphone',
#  'train/1271.jpg': 'a man holding a plaque in front of a barn',
#  'train/1272.jpg': 'a group of people standing in front of a desk',
#  'train/1278.jpg': 'a group of people sitting in a meeting with a shows on a screen',
#  'train/1279.jpg': 'a group of people standing together in a room',
#  'train/1280.jpg': 'a woman sitting in front of a television',
#  'train/1281.jpg': 'two people walking in a european museum with a painting',
#  'train/1282.jpg': 'a group of people standing in a room with a chandeliers',
#  'train/1288.jpg': 'a group of people standing in a room',
#  'train/1289.jpg': 'a man in a suit and tie standing in front of a person with a cell phone',
#  'train/1290.jpg': 'a man in a chair in front of a crowd of people',
#  'train/1291.jpg': 'a group of children sitting on the ground eating food',
#  'train/1292.jpg': 'a woman sitting in a auditorium holding a microphone',
#  'train/1298.jpg': 'a man in a suit and tie sitting in a red chair',
#  'train/1299.jpg': 'two men sitting in a chair in front of a room with a table',
#  'train/1300.jpg': 'a note on the top of a desk with a book',
#  'train/1301.jpg': 'a picture of a man in glasses on a table',
#  'train/1302.jpg': 'a group of people sitting around a candle in a room',
#  'train/1308.jpg': 'a group of people sitting in a room',
#  'train/1309.jpg': 'a woman and men standing at a podium',
#  'train/1310.jpg': 'a billboard on the side of a street',
#  'train/1311.jpg': 'a man riding on top of a boat in the ocean',
#  'train/1312.jpg': 'a group of children and a man standing around a table',
#  'train/1318.jpg': 'a woman with a black and white shirt and a smile',
#  'train/1319.jpg': 'a group of people walking down a street with protest signs',
#  'train/1320.jpg': 'a group of gentlemen standing in front of a speaks at a podium',
#  'train/1321.jpg': 'a man in a suit and tie in a room',
#  'train/1322.jpg': 'a group of people standing in front of a luggage',
#  'train/1328.jpg': 'a group of people standing in front of a building',
#  'train/1329.jpg': 'a group of toothbrushes on top of a blue table',
#  'train/1330.jpg': 'a woman holding a sweater and a person in front of a library',
#  'train/1331.jpg': 'a man standing in front of a wall with a face',
#  'train/1332.jpg': 'a man in a suit and red tie walking in a field',
#  'train/1338.jpg': 'a black and white photo of a woman sitting in the grass',
#  'train/1339.jpg': 'a group of people standing in front of a building',
#  'train/1340.jpg': 'a man sitting at a podium in front of a person',
#  'train/1341.jpg': 'a man riding a skateboard on top of a wall',
#  'train/1342.jpg': 'a woman standing in front of a table with a horse',
#  'train/1348.jpg': 'a group of people standing on a street with banners',
#  'train/1349.jpg': 'a group of people walking down a street',
#  'train/1350.jpg': 'a sign on the side of a street with a person',
#  'train/1351.jpg': 'a group of people sitting in a room',
#  'train/1352.jpg': 'a man standing in the back of a truck',
#  'train/1358.jpg': 'a man in a black suit and tie',
#  'train/1359.jpg': 'a man standing in front of a crowd of people in a church',
#  'train/1360.jpg': 'a man in a suit and person with a microphone',
#  'train/1361.jpg': 'a man in a hat on a table with a person on a us national emblem on a podium',
#  'train/1362.jpg': 'a this is a of a view of a hockey game',
# ...
#  'train/1550.jpg': 'a group of people sitting on a bench',
#  'train/1551.jpg': 'three men sitting at a table with a business suit and tie',
#  'train/1552.jpg': 'the person in a suit and helmet on the back of a man in front of royal water a person in a suit and person',
#  'train/1558.jpg': 'a group of people standing next to each other',
#  'train/1559.jpg': 'a man and a woman sitting on a bench with a dog',
#  'train/1560.jpg': 'a group of people standing next to each other',
#  'train/1561.jpg': 'two children riding colombia in front of a building',
#  'train/1562.jpg': 'a man taking a picture of himself in a window',
#  'train/1568.jpg': 'a group of people sitting in front of a audience of televisions',
#  'train/1569.jpg': 'a man in a suit and tie standing in doorway of a car',
#  'train/1570.jpg': 'a man holding a gun in front of a table',
#  'train/1571.jpg': 'the right of the woman standing at a podium',
#  'train/1572.jpg': 'a group of cars on a highway with a red train',
#  'train/1578.jpg': 'a group of people standing in a room',
#  'train/1579.jpg': 'a group of people standing on a room with lighting',
#  'train/1580.jpg': 'a man standing in a hospital room with a bed',
#  'train/1581.jpg': 'a man standing at a podium in front of a table',
#  'train/1582.jpg': 'a person walking in front of a door in a street',
#  'train/1588.jpg': 'a group of people standing in a field with a tree',
#  'train/1589.jpg': 'a man in a suit and tie standing in a crowd',
#  'train/1590.jpg': 'a man in a suit and tie standing on a stage',
#  'train/1591.jpg': 'a man sitting at a table with a microphone',
#  'train/1592.jpg': 'a man giving a fist in front of a podium',
#  'train/1598.jpg': 'two men standing in front of a truck',
#  'train/1599.jpg': 'a group of men walking through a door',
#  'train/1600.jpg': 'a group of people standing in front of a camera',
#  'train/1601.jpg': 'a group of people standing on a street eating food',
#  'train/1602.jpg': 'a man accounted on top of a podium',
#  'train/1608.jpg': 'a group of people standing in front of a uncomfortable',
#  'train/1609.jpg': 'a group of people standing in front of a building with a gift boxes',
#  'train/1610.jpg': 'a man in a suit and tie standing in front of a person',
#  'train/1611.jpg': 'a person walking on the beach next to the water',
#  'train/1612.jpg': 'the president in a suit and tie standing in front of a light',
#  'train/1618.jpg': 'a man standing on a stage with a microphone',
#  'train/1619.jpg': 'a man standing in front of a adds to an airplane',
#  'train/1620.jpg': 'a man in a suit and tie standing in front of a table',
#  'train/1621.jpg': 'a group of people walking in the rain with flags',
#  'train/1622.jpg': 'a man sitting in front of a man in a military uniform',
#  'train/1628.jpg': 'two men sitting at a table during a sitting in a table',
#  'train/1629.jpg': 'a crowd of people standing in a person standing in a street',
#  'train/1630.jpg': 'a man standing on top of a runway with a person',
#  'train/1631.jpg': 'a man in suit and tie standing on a street with a crowd of people',
#  'train/1632.jpg': 'a group of people walking around in a building',
#  'train/1638.jpg': 'a group of people sitting in a crowd',
#  'train/1639.jpg': 'a crowd of people sitting in a street with umbrellas',
#  'train/1640.jpg': 'a close up of a picture of a man on the side of a flag',
#  'train/1641.jpg': 'a group of police officers standing next to a blue depicts tape',
#  'train/1642.jpg': 'there are men in suits walking down a hall',
#  'train/1648.jpg': 'a view of a city at night with tall buildings',
#  'train/1649.jpg': 'a man and a child walking next to each other',
#  'train/1650.jpg': 'a man sitting at a table with a suit and tie',
#  'train/1651.jpg': 'a man in a suit and suit and person in the air with a crowd',
#  'train/1652.jpg': 'a group of people sitting in front of a table',
#  'train/1658.jpg': 'a man standing in front of a gold coin on a podium',
#  'train/1659.jpg': 'a man sitting on a bed with a watch on his hand',
#  'train/1660.jpg': 'a dirt road in a field with a hill with houses',
#  'train/1661.jpg': 'a man standing in front of a group of people in a room',
#  'train/1662.jpg': 'a man standing in a room holding a microphone',
#  'train/1668.jpg': 'a young boy standing in front of a group of people',
#  'train/1669.jpg': 'a woman holding a microphone in front of a room',
#  'train/1670.jpg': 'a group of people sitting in front of a screen',
#  'train/1671.jpg': 'a group of people walking down a street with signs',
#  'train/1672.jpg': 'a man with blue eyes sitting at a event',
#  'train/1678.jpg': 'two men walking in a hall with suits and a tie',
#  'train/1679.jpg': 'a group of people standing in front of a crowd of people',
#  'train/1680.jpg': 'a group of yellow taxi cabs on a city street',
#  'train/1681.jpg': 'a man sitting on a couch in a living room',
#  'train/1682.jpg': 'this is a picture of president bush sitting on a podium',
#  'train/1688.jpg': 'a man and woman standing next to a microphone',
#  'train/1689.jpg': 'a group of people standing in a company kitchen',
#  'train/1690.jpg': 'two men sitting in front of a table with a suit and red tie',
#  'train/1691.jpg': 'a man standing in a pile of bark and a nature person',
#  'train/1692.jpg': 'a group of people standing next to each other',
#  'train/1698.jpg': 'a group of people standing in a room',
#  'train/1699.jpg': 'a man and a woman walking down the hallway',
#  'train/1700.jpg': 'two men walking on top of a ship with flags',
#  'train/1701.jpg': 'a man standing in front of a crowd of people',
#  'train/1702.jpg': 'a group of men in suits and ties standing in a room',
#  'train/1708.jpg': 'a book sitting on top of a table with a table',
#  'train/1709.jpg': 'a man standing on top of a microphone',
#  'train/1710.jpg': 'a woman sitting at a table with a microphone',
#  'train/1711.jpg': 'a group of people standing in front of a camera',
#  'train/1712.jpg': 'a group of people sitting around a table',
#  'train/1718.jpg': 'a man standing in front of a microphone',
#  'train/1719.jpg': 'a man standing on top of a crowd of people holding a blue and white flag',
#  'train/1720.jpg': 'two men standing on top of a stage with microphones',
#  'train/1721.jpg': 'a man in a suit and tie standing in a room',
#  'train/1722.jpg': 'a white man in a suit and red tie',
#  'train/1728.jpg': 'a group of people holding signs in the water',
#  'train/1729.jpg': 'a black and white photo of a woman wearing sunglasses',
#  'train/1730.jpg': 'a group of people standing on a stage with microphones',
#  'train/1731.jpg': 'a group of people standing in front of a display case',
#  'train/1732.jpg': 'a man standing before a crowd of people at a podium',
#  'train/1738.jpg': 'a view of a classroom with desks and sign on the wall',
#  'train/1739.jpg': 'a group of people standing next to a table with signs',
#  'train/1740.jpg': 'a man standing on a city street with a woman',
#  'train/1741.jpg': 'a red and white building with a red building',
#  'train/1742.jpg': 'a desk with a computer on top of it',
#  'train/1748.jpg': 'a man in a suit and tie standing in a room',
#  'train/1749.jpg': 'a group of people standing around a table',
#  'train/1750.jpg': 'two young children standing in front of a car',
#  'train/1751.jpg': 'a person riding a skateboard down a street',
#  'train/1752.jpg': 'a group of people sitting in a hall with a person person',
#  'train/1758.jpg': 'a group of people standing in a street in a building',
#  'train/1759.jpg': 'a man in a suit and tie standing in a table',
#  'train/1760.jpg': 'a group of people standing in a field with trees',
#  'train/1761.jpg': 'a man in glasses stands in front of a group of people',
#  'train/1762.jpg': 'a man in a suit and tie standing in a room',
#  'train/1768.jpg': 'a group of people sitting in a living room',
#  'train/1769.jpg': 'a group of people standing in front of a tree',
#  'train/1770.jpg': 'a stone wall with a rock wall and a building',
#  'train/1771.jpg': 'two men sitting at a desk with a sign',
#  'train/1772.jpg': 'two soldiers standing in front of a tent with a gun',
#  'train/1778.jpg': 'a group of men standing in front of a podium',
#  'train/1779.jpg': 'a man in a suit and tie standing in front of a field',
#  'train/1780.jpg': 'a man standing on a skateboard in a crowd',
#  'train/1781.jpg': 'a street sign in front of a factory',
#  'train/1782.jpg': 'a woman standing in front of a market with luggage',
#  'train/1788.jpg': 'a group of people standing in front of a crowd of greek government',
#  'train/1789.jpg': 'a group of people standing in front of an airplane',
#  'train/1790.jpg': 'a black and white photo of a man and two children',
#  'train/1791.jpg': 'a man in a blue suit and a police officer hand in hand',
#  'train/1792.jpg': 'a man in a suit and tie standing in front of a uncomfortable',
#  'train/1798.jpg': 'a man holding a book in front of a church',
#  'train/1799.jpg': 'a group of people holding signs on a street',
#  'train/1800.jpg': 'a couple of people standing next to each other',
#  'train/1801.jpg': 'a man in a suit and tie standing in a room',
#  'train/1802.jpg': 'a group of men holding signs in a street',
#  'train/1808.jpg': 'a man wearing a white suit and tie',
#  'train/1809.jpg': 'a group of people standing in front of a building with cameras',
#  'train/1810.jpg': 'a group of people walking down a street with a building',
#  'train/1811.jpg': 'this is a picture of a man in a suit and person with a hat',
#  'train/1812.jpg': 'two women sitting at a table with a person',
#  'train/1818.jpg': 'a group of men walking down a street',
#  'train/1819.jpg': 'a group of men sitting in front of a ceremony',
#  'train/1820.jpg': 'a group of people sitting in a room with a table',
#  'train/1821.jpg': 'a group of people walking down a street with signs',
#  'train/1822.jpg': 'the president in front of a microphone in a room',
#  'train/1828.jpg': 'a group of men sitting on a stage with microphones',
#  'train/1829.jpg': 'a man sitting on a bench with his arm in a tie',
#  'train/1830.jpg': 'a group of men standing in front of a car',
#  'train/1831.jpg': 'a group of people standing in a street with signs',
#  'train/1832.jpg': 'a man standing in front of a microphone',
#  'train/1838.jpg': 'a group of people sitting in a room with a table',
#  'train/1839.jpg': 'a man sitting at a podium with a computer',
#  'train/1840.jpg': 'a group of people sitting in a room',
#  'train/1841.jpg': 'a group of people standing around a line in a table',
#  'train/1842.jpg': 'a woman standing in front of a blue suit and a microphone',
#  'train/1848.jpg': 'a group of people standing in front of a building with an umbrella',
#  'train/1849.jpg': 'a group of women standing next to a bunch of shoes',
#  'train/1850.jpg': 'a black and white photo of a man wearing a suit and tie',
#  'train/1851.jpg': 'a group of men standing in front of a everyone of people in a room',
#  'train/1852.jpg': 'a group of people standing in front of a stage with signs',
#  'train/1858.jpg': 'a group of people walking down a street with signs',
#  'train/1859.jpg': 'a man sitting at a table with a glass of water',
#  'train/1860.jpg': 'the president standing in front of a crowd of people',
#  'train/1861.jpg': 'a man standing next to a wall with a dog',
#  'train/1862.jpg': 'a group of people sitting on the ground',
#  'train/1868.jpg': 'a group of people standing in a room',
#  'train/1869.jpg': 'a woman standing at a desk with a paper',
#  'train/1870.jpg': 'a man walking down a lobby with a luggage',
#  'train/1871.jpg': 'a group of people standing around a table',
#  'train/1872.jpg': 'a man sitting on a red carpet with a microphone',
#  'train/1878.jpg': 'a group of people sitting at a podium in front of a room',
#  'train/1879.jpg': 'a book with a picture of a person on it',
#  'train/1880.jpg': 'two men sitting on top of a staircase',
#  'train/1881.jpg': 'a group of people standing in front of a table with cameras',
#  'train/1882.jpg': 'two people standing in the snow with drums',
#  'train/1888.jpg': 'a beautiful person sitting on the top of a cell phone',
#  'train/1889.jpg': 'two men sitting at a desk in a room',
#  'train/1890.jpg': 'a man and a woman standing in front of a building',
#  'train/1891.jpg': 'a group of people standing on top of a stage',
#  'train/1892.jpg': 'a group of people with pink smoke in the air',
#  'train/1898.jpg': 'a group of people playing with a ball on the beach',
#  'train/1899.jpg': 'two hands and a person writing on a card on a table',
#  'train/1900.jpg': 'a woman holding a microphone in front of a podium',
#  'train/1901.jpg': 'a woman standing in front of a podium',
#  'train/1902.jpg': 'a group of people walking down a street holding signs',
#  'train/1908.jpg': 'a group of people standing in front of a sign',
#  'train/1909.jpg': 'a group of people making designs on a table',
#  'train/1910.jpg': 'a woman standing in front of a wall of gun vertical style government',
#  'train/1911.jpg': 'a group of men in suits and red ties',
#  'train/1912.jpg': 'a man standing in front of a crowd of people',
#  'train/1918.jpg': 'two men standing next to a microphone in front of a flag',
#  'train/1919.jpg': 'a i was standing in front of a building with a clock tower',
#  'train/1920.jpg': 'a woman standing in front of a microphone',
#  'train/1921.jpg': 'a dining room with a table and a person',
#  'train/1922.jpg': 'a man standing in front of a crowd of people with a microphone',
#  'train/1928.jpg': 'a man in a suit and tie standing at a microphone',
#  'train/1929.jpg': 'a man standing in front of a usa flag in a church',
#  'train/1930.jpg': 'a group of people walking down a street with flags',
#  'train/1931.jpg': 'a man standing at a podium with a person in the air',
#  'train/1932.jpg': 'a man sitting in a chair playing a video game',
#  'train/1938.jpg': 'a man in a suit and tie standing in front of a building',
#  'train/1939.jpg': 'a group of people standing in a factory',
#  'train/1940.jpg': 'a man sitting on a window high window in a kitchen',
#  'train/1941.jpg': 'a woman holding a hand holding a bag in a library',
#  'train/1942.jpg': 'two men walking in front of a royal room',
#  'train/1948.jpg': 'a group of people standing around a table with a person',
#  'train/1949.jpg': 'a young boy walking in front of a room with a building',
#  'train/1950.jpg': 'two men having fun in front of a wall with confetti',
#  'train/1951.jpg': 'a group of people sitting in a room with a table',
#  'train/1952.jpg': 'a group of people standing on a me on a construction site',
#  'train/1958.jpg': 'a woman standing in a room with a microphone',
#  'train/1959.jpg': 'the president standing in front of a microphones and a person',
#  'train/1960.jpg': 'a man holding a person in the air with a back person',
#  'train/1961.jpg': 'two people sitting at a table with person on a person',
#  'train/1962.jpg': 'a man standing in front of a wall',
#  'train/1968.jpg': 'a person holding a card in front of a street',
#  'train/1969.jpg': 'a group of people standing in a park',
#  'train/1970.jpg': 'a woman sitting at a podium in front of a microphone',
#  'train/1971.jpg': 'a wind mill in the sky with a light',
#  'train/1972.jpg': 'a tent with an umbrella in a field',
#  'train/1978.jpg': 'a man in a suit and tie standing on a street',
#  'train/1979.jpg': 'a we are in a factory with a person standing on a as you see this photo',
#  'train/1980.jpg': 'a man sitting in a chair with a dog',
#  'train/1981.jpg': 'a young man standing in front of a building with a white t shirt',
#  'train/1982.jpg': 'a man standing in front of a crowd of people who have a microphone',
#  'train/1988.jpg': 'a man in a suit and tie walking on a street at night',
#  'train/1989.jpg': 'a man standing in front of a house with a sign',
#  'train/1990.jpg': 'a man riding a skateboard down a street',
#  'train/1991.jpg': 'a group of children sitting on a slide in a playground',
#  'train/1992.jpg': 'a group of people standing on a stage with a person',
#  'train/1998.jpg': 'a man sitting at a table with a laptop computer',
#  'train/1999.jpg': 'a group of people sitting in front of a room',
#  ...}

# %%
len(image_cap_dict)
# Out:
# 10988

# %%
image_cap_dict.to_json('image_cap_dict.json')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /root/thesis/X-VLM/gen_caption_for_train.ipynb Cell 13' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B172.29.64.76/root/thesis/X-VLM/gen_caption_for_train.ipynb#ch0000024vscode-remote?line=0'>1</a> image_cap_dict.to_json('image_cap_dict.json')
#
# AttributeError: 'dict' object has no attribute 'to_json'

# %%
with open("image_cap_dict.json", "w") as outfile:
    json.dump(image_cap_dict, outfile)
